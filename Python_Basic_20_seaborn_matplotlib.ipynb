# %% [markdown]
# <a href="https://colab.research.google.com/github/Manojgharge07/DataScience-Mentorship-Python-Basic/blob/main/Python_Basic_20_seaborn_matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# importing packages
import seaborn as sns

#loading dataset
df = sns.load_dataset("iris")

df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df.species.value_counts()
# Out:
# setosa        50
# versicolor    50
# virginica     50
# Name: species, dtype: int64

# %%
df.shape
# Out:
# (150, 5)

# %%
df.nunique()
# Out:
# sepal_length    35
# sepal_width     23
# petal_length    43
# petal_width     22
# species          3
# dtype: int64

# %%
df["species"].nunique()
# Out:
# 3

# %%
df["sepal_length"].nunique()
# Out:
# 35

# %%
df.petal_length.nunique()
# Out:
# 43

# %%
df["petal_width"].nunique()
# Out:
# 22

# %%
df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
#For specific flower
df_setosa = df[df["species"] == "setosa"]

# %%
df_setosa.head(10)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa
# 5           5.4          3.9           1.7          0.4  setosa
# 6           4.6          3.4           1.4          0.3  setosa
# 7           5.0          3.4           1.5          0.2  setosa
# 8           4.4          2.9           1.4          0.2  setosa
# 9           4.9          3.1           1.5          0.1  setosa

# %%
df_setosa.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count      50.00000    50.000000     50.000000    50.000000
# mean        5.00600     3.428000      1.462000     0.246000
# std         0.35249     0.379064      0.173664     0.105386
# min         4.30000     2.300000      1.000000     0.100000
# 25%         4.80000     3.200000      1.400000     0.200000
# 50%         5.00000     3.400000      1.500000     0.200000
# 75%         5.20000     3.675000      1.575000     0.300000
# max         5.80000     4.400000      1.900000     0.600000

# %%
#For specific flower
df_versicolor = df[df["species"] == "versicolor"]

# %%
df_versicolor.head()
# Out:
#     sepal_length  sepal_width  petal_length  petal_width     species
# 50           7.0          3.2           4.7          1.4  versicolor
# 51           6.4          3.2           4.5          1.5  versicolor
# 52           6.9          3.1           4.9          1.5  versicolor
# 53           5.5          2.3           4.0          1.3  versicolor
# 54           6.5          2.8           4.6          1.5  versicolor

# %%
df_versicolor.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count     50.000000    50.000000     50.000000    50.000000
# mean       5.936000     2.770000      4.260000     1.326000
# std        0.516171     0.313798      0.469911     0.197753
# min        4.900000     2.000000      3.000000     1.000000
# 25%        5.600000     2.525000      4.000000     1.200000
# 50%        5.900000     2.800000      4.350000     1.300000
# 75%        6.300000     3.000000      4.600000     1.500000
# max        7.000000     3.400000      5.100000     1.800000

# %%
#Draw lineplot
sns.lineplot (x="sepal_length", y="sepal_width", data=df)

# %%
#Draw lineplot
sns.lineplot(x="petal_length", y="petal_width", data=df)

# %%
#Draw lineplot
sns.lineplot (x="sepal_length", y="petal_length", data=df)

# %%
#To set the xlim & ylim
#import packages

import seaborn as sns
import matplotlib.pyplot as plt

#loading dataset
df = sns.load_dataset("iris")

#Draw lineplot
sns.lineplot (x="sepal_length", y="sepal_width", data=df)

#setting the plot limit
plt.xlim(5)

plt.show()

# %%
# To set the xlim & ylim
# Import packages

import seaborn as sns
import matplotlib.pyplot as plt

#loading data set
df = sns.load_dataset("iris")

#Draw lineplot
sns.lineplot (x="petal_length", y="petal_width", data=df)

#Setting the xlim of plot
plt.xlim(2)

plt.show()

# %%
# To set dark theme
# import packages

import seaborn as sns
import matplotlib.pyplot as plt

#loading data set
df = sns.load_dataset("iris")
sns.set_style("dark")

#Draw lineplot
sns.lineplot (x="sepal_length", y="sepal_width",data=df)

#change the theme
plt.show()

# %%
#import packages
#change figure size

import seaborn as sns
import matplotlib.pyplot as plt

#loading data set

df = sns.load_dataset("iris")

#change fig size
plt.figure(figsize=(10,5))

#Draw lineplot
sns.lineplot (x="sepal_length", y="sepal_width", data=df)

#Remove the spines
sns.despine()

plt.show()

# %%
#import packages
#change figure size

import seaborn as sns
import matplotlib.pyplot as plt

#loading data set

df = sns.load_dataset("iris")

#change fig size
plt.figure(figsize=(15,5))

#Draw lineplot
sns.lineplot (x="sepal_length", y="sepal_width", data=df)

#Remove the spines
sns.despine()

plt.show()

# %%
#import packages
#change figure size

import seaborn as sns
import matplotlib.pyplot as plt

#loading data set

df = sns.load_dataset("iris")

#change fig size
plt.figure(figsize=(15,10))

#Draw lineplot
sns.lineplot (x="sepal_length", y="sepal_width", data=df)

#Remove the spines
sns.despine()

plt.show()

# %%
#import packages
#change figure size

import seaborn as sns
import matplotlib.pyplot as plt

#loading data set

df = sns.load_dataset("iris")

#change fig size
plt.figure(figsize=(12,7))

#Draw lineplot
sns.lineplot (x="petal_length", y="petal_width", data=df)

#Remove the spines
sns.despine()

plt.show()

# %%
#import packages
#change figure size

import seaborn as sns
import matplotlib.pyplot as plt

#loading data set

df = sns.load_dataset("iris")

#change fig size
plt.figure(figsize=(12,7))

#Draw lineplot
sns.lineplot (x="petal_length", y="petal_width", data=df)


plt.show()

# %%
#Multiple no of graph
#Import packages
import seaborn as sns
import matplotlib.pyplot as plt

#Loading Data set
df = sns.load_dataset("iris")
sns.set_style("whitegrid")

def graph():
  sns.lineplot(x="petal_length", y="petal_width", data=df)

fig =plt.figure(figsize= (10,6))


ax1= fig.add_axes([0.4,0.4,0.9,0.9])

graph()

ax2= fig.add_axes([0.5,0.9,0.3,0.3])

graph()

plt.show()

# %%
#Multiple no of graph
#Import packages
import seaborn as sns
import matplotlib.pyplot as plt

#Loading Data set
df = sns.load_dataset("iris")
sns.set_style("white")

def graph():
  sns.lineplot(x="sepal_length", y="sepal_width", data=df)
  def graph2():
    sns.lineplot(x="sepal_length", y="sepal_width", data=verginica)

fig =plt.figure(figsize= (10,6))


ax1= fig.add_axes([0.4,0.3,0.9,0.9])

graph()

ax2= fig.add_axes([0.9,0.9,0.3,0.3])

graph()

plt.show()

# %%
#Adding subplot graphs
#import packages

import seaborn as sns
import matplotlib.pyplot as plt

#Loading data
df = sns.load_dataset("iris")

def graph():
  sns.lineplot(x="sepal_length", y="sepal_width", data=df)

#Fig size
plt.figure(figsize=(12,5))


#Adding subplot
plt.subplot(121)
graph()


#Adding another subplot
plt.subplot(122)
graph()

plt.show()

# %% [markdown]
# def graph():
#   sns.lineplot(x="petal_length", y="petal_width", data=df)

# %%
#Adding subplot graphs
#import packages

import seaborn as sns
import matplotlib.pyplot as plt

#Loading data
df = sns.load_dataset("iris")

def graph():
  sns.lineplot(x="sepal_length", y="sepal_width", data=df)

#Fig size
plt.figure(figsize=(14,5))


#Adding subplot
plt.subplot(121)
graph()

def graph():
   sns.lineplot(x="petal_length", y="petal_width", data=df)


#Adding another subplot
plt.subplot(122)
graph()

plt.show()

# %%
from IPython.core.pylabtools import figsize
# FaceGrid of graph
#import packages

import seaborn as sns
import matplotlib.pyplot as plt

#Loading data
df = sns.load_dataset("iris")

plot = sns.FacetGrid(df, col="species")
plot.map(plt.plot, "sepal_length")

#figure
plt.figure(figsize=(12,4))

plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
# FaceGrid of graph
#import packages

import seaborn as sns
import matplotlib.pyplot as plt

#Loading data
df = sns.load_dataset("iris")

plot = sns.FacetGrid(df,col="species")
plot.map(plt.plot, "petal_length")

#figure size
plt.figure(figsize=(12,4))

plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
import seaborn as sns

#loading data 
df = sns.load_dataset("iris")

#create the relplot
sns.relplot(x="sepal_length", y="species", data=df)

plt.figure(figsize=(14,4))

plt.show()

# %%
import seaborn as sns

#loading data 
df = sns.load_dataset("iris")

#create the relplot
sns.relplot(x="sepal_width", y="species", data=df)

plt.show()

# %%
import seaborn as sns

#loading data 
df = sns.load_dataset("iris")

#create the relplot
sns.relplot(x="petal_length", y="species", data=df)

plt.figure(figsize=(14,4))
plt.show()

# %%
import seaborn as sns

#loading data 
df = sns.load_dataset("iris")

#create the relplot
sns.relplot(x="sepal_width", y="species", data=df)

plt.show()

# %%
import seaborn as sns
sns.scatterplot(x="petal_length", y="petal_width", data=df)
plt.show()

# %%
import seaborn as sns
sns.scatterplot(x="sepal_length", y="sepal_width", data=df)
plt.show()

# %%
#line plot
#import packages
import seaborn as sns
import matplotlib.pyplot as plt

#loading data
df = sns.load_dataset("iris")

sns.lineplot(x="petal_length", y="species", data=df)
plt.show()

# %%
#line plot
#import packages
import seaborn as sns
import matplotlib.pyplot as plt

#loading data
df = sns.load_dataset("iris")

sns.lineplot(x="petal_width", y="species", data=df)
plt.show()

# %%
#line plot
#import packages
import seaborn as sns
import matplotlib.pyplot as plt

#loading data
df = sns.load_dataset("iris")

sns.lineplot(x="sepal_length", y="species", data=df)
plt.show()

# %%
#line plot
#import packages
import seaborn as sns
import matplotlib.pyplot as plt

#loading data
df = sns.load_dataset("iris")

sns.lineplot(x="sepal_width", y="species", data=df)
plt.show()

# %%
#import packages
import seaborn as sns
import warnings as filterwarnings

#loading data
df = sns.load_dataset("tips")

df.head(10)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
# 5       25.29  4.71    Male     No  Sun  Dinner     4
# 6        8.77  2.00    Male     No  Sun  Dinner     2
# 7       26.88  3.12    Male     No  Sun  Dinner     4
# 8       15.04  1.96    Male     No  Sun  Dinner     2
# 9       14.78  3.23    Male     No  Sun  Dinner     2

# %%
df.tail()
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2

# %%
df.sample(5)
# Out:
#      total_bill   tip     sex smoker  day    time  size
# 13        18.43  3.00    Male     No  Sun  Dinner     4
# 22        15.77  2.23  Female     No  Sat  Dinner     2
# 76        17.92  3.08    Male    Yes  Sat  Dinner     2
# 181       23.33  5.65    Male    Yes  Sun  Dinner     2
# 226       10.09  2.00  Female    Yes  Fri   Lunch     2

# %%
#background style
import seaborn as sns
sns.set_style("darkgrid")

#barplot
sns.barplot(x="sex", y="tip", data=df, palette="plasma")
plt.show()

# %%
#background style
import seaborn as sns
sns.set_style("dark")

#barplot
sns.barplot(x="day", y="total_bill", data=df, palette="plasma")
plt.show()

# %%
#background style
import seaborn as sns
sns.set_style("whitegrid")

#barplot
sns.barplot(x="smoker", y="tip", data=df, palette="Paired")
plt.show()

# %%
#background style
import seaborn as sns
sns.set_style("white")

#barplot
sns.barplot(x="sex", y="size", data=df, palette="husl")
plt.show()

# %%
import seaborn as sns
sns.color_palette("hls", 8)
# Out:
# [(0.86, 0.3712, 0.33999999999999997),
#  (0.86, 0.7612000000000001, 0.33999999999999997),
#  (0.5688000000000001, 0.86, 0.33999999999999997),
#  (0.33999999999999997, 0.86, 0.5012000000000001),
#  (0.33999999999999997, 0.8287999999999999, 0.86),
#  (0.33999999999999997, 0.43879999999999986, 0.86),
#  (0.6311999999999998, 0.33999999999999997, 0.86),
#  (0.86, 0.33999999999999997, 0.6987999999999996)]

# %%
#background style
import seaborn as sns
sns.set_style("dark")

#barplot
sns.barplot(x="sex", y="size", data=df, palette="hls")
plt.show()

# %%
#background style
import numpy as np
import seaborn as sns
sns.set_style("darkgrid")

#barplot
sns.barplot(x="day", y="total_bill", data=df, palette="plasma", estimator=np.std)
plt.show()

# %%
import seaborn as sns
sns.countplot(x="day",data=df)
plt.show()

# %%
import seaborn as sns
sns.countplot(x="smoker",data=df)
plt.show()

# %%
import seaborn as sns
sns.countplot(x="time",data=df)
plt.show()

# %%
#quality check
df.day.value_counts()
# Out:
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: day, dtype: int64

# %%
#quality check
df.time.value_counts()
# Out:
# Dinner    176
# Lunch      68
# Name: time, dtype: int64

# %%
#quality check
df.smoker.value_counts()
# Out:
# No     151
# Yes     93
# Name: smoker, dtype: int64

# %%
#quality check
df.total_bill.value_counts()
# Out:
# 13.42    3
# 13.81    2
# 15.98    2
# 17.92    2
# 10.07    2
#         ..
# 24.71    1
# 21.16    1
# 28.97    1
# 22.49    1
# 18.78    1
# Name: total_bill, Length: 229, dtype: int64

# %%
import seaborn as sns
sns.boxplot(x="day", y="tip", data=df, hue="sex")
plt.show()

# %%
import seaborn as sns
sns.boxplot(x="sex", y="total_bill", data=df, hue="time")
plt.show()

# %%
df.sex.value_counts()
# Out:
# Male      157
# Female     87
# Name: sex, dtype: int64

# %%
from pandas.core.frame import DataFrame
import pandas as pd

df = pd.DataFrame(df["total_bill"])
df.describe()
# Out:
#        total_bill
# count  244.000000
# mean    19.785943
# std      8.902412
# min      3.070000
# 25%     13.347500
# 50%     17.795000
# 75%     24.127500
# max     50.810000
