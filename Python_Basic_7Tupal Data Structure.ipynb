# %% [markdown]
# <a href="https://colab.research.google.com/github/Manojgharge07/DataScience-Mentorship-Python-Basic/blob/main/Python_Basic_7Tupal%20Data%20Structure.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Tuple
#
# 1. Tuple is exactly same as List except that it is immutable. i.e once we creates Tuple object, we cannot perform any changes in that object. Hence Tuple is Read only version of List.
# 2. If our data is fixed and never changes then we should go for Tuple.
# 3. Insertion Order is preserved Duplicates are allowed Heterogeneous objects are allowed.
# 4. We can preserve insertion order and we can differentiate duplicate objects by using index. Hence index will play very important role in Tuple also.
# 5. Tuple support both +ve and -ve index. +ve index means forward direction (from left to right) and -ve index means backward direction (from right to left)
# 6. We can represent Tuple elements within Parenthesis and with comma seperator.

# %%
t=(1,2,3,4,5,6,7)
print(type(t))
print(t)
# Out:
# <class 'tuple'>
# (1, 2, 3, 4, 5, 6, 7)

# %%
t=10,11,12,13,14,15
t
print(type(t))
# Out:
# <class 'tuple'>

# %% [markdown]
# Q) Which of the following are valid Tuples?
#
# 1) t=()  #Tuple
#
# 2) t=10,20,30,40 #Tuple
#
# 3) t=10  #Not tuple
#
# 4)t = (10,)  #Tuple
#
# 5) t=(10,20,30,40)  #Tuple
#
# 6) t = [10,20]  #Not tuple
#
# tuple(t)  #Tuple
# Accessing Elements of Tuple:
#
# We can access either by index or by slice operator

# %%
#By using Index:
t=(10,20,30,40,50,60,70,80,90)
print(t[0])#10
print(t[-1])#90
print(t[-4])
print(t[100])#IndexError: tuple index out of range
# Out:
# 10
# 90
# 60
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-6-39c96e142527> in <module>()
#       4 print(t[-1])#90
#       5 print(t[-4])
# ----> 6 print(t[100])#IndexError: tuple index out of range
#
# IndexError: tuple index out of range

# %%
t=(10,11,12,13,14,15)
print(t[:])
print(t[1:4])
print(t[:])
print(t[::2])
# Out:
# (10, 11, 12, 13, 14, 15)
# (11, 12, 13)
# (10, 11, 12, 13, 14, 15)
# (10, 12, 14)

# %% [markdown]
# Mathematical Operators for Tuple:
#
# We can apply + and * operators for tuple

# %%
# 1) Concatenation Operator (+):
a=(10,11,12,13,14,15)
b=(13,14,15,16,17,18)
c=a+b
print(c)
# Out:
# (10, 11, 12, 13, 14, 15, 13, 14, 15, 16, 17, 18)

# %%
#2) Multiplication Operator OR Repetition Operator (*):
a=(5,6,7)
b=a*3
print(b)
# Out:
# (5, 6, 7, 5, 6, 7, 5, 6, 7)

# %% [markdown]
# Important Functions of Tuple:

# %%
#1. len():
t=(1,2,3,4,5)
len(t)
# Out:
# 5

# %%
#1. len():
t=(1,2,3,4,5,6,3,4,2,1,5,7,6,3,2,1,3,5,1,2)
print(t.count(3))
print(t.count(1))
t.count(4)
# Out:
# 4
# 4
# 2

# %%
# 3. index(): Returns index of first occurrence of the given element.
# If the specified element is not available then we will get ValueError:
t=(10,11,12,13,14,15)
print(t.index(13))
print(t.index(10))
# Out:
# 3
# 0

# %%
# 4. sorted(): To sort elements based on default natural sorting order:
a=(10,11,12,10,10,13,12,13,14)
b=sorted(a)
print(b)
# Out:
# [10, 10, 10, 11, 12, 12, 13, 13, 14]

# %%
#We can sort according to reverse of default natural sorting order as follows:
c = sorted(a, reverse = True)
print(c)
# Out:
# [14, 13, 13, 12, 12, 11, 10, 10, 10]

# %%
# 5. min() and max() functions:
#These functions return min and max values according to default natural sorting order.
t=(10,20,40,10,30,10,10,20,50)
print(min(t))
print(max(t))
# Out:
# 10
# 50

# %% [markdown]
# Q. What do you mean by packing and unpacking of tuple?(explain with the help of code)
#
# Tuple Comprehension:
#
# Tuple Comprehension is not supported by Python.
#
# t = ( x**2 for x in range(1,6))
#
# Here we are not getting tuple object and we are getting generator object.
#
# 1) t= ( x**2 for x in range(1,6))
#
# 2) print(type(t))
#
# 3) for x in t:
#
# 4) print(x)

# %%
a = ( x**2 for x in range(1,7))
print(type(a))
for x in a:
  print(a)
# Out:
# <class 'generator'>
# <generator object <genexpr> at 0x7f7bff5e01d0>
# <generator object <genexpr> at 0x7f7bff5e01d0>
# <generator object <genexpr> at 0x7f7bff5e01d0>
# <generator object <genexpr> at 0x7f7bff5e01d0>
# <generator object <genexpr> at 0x7f7bff5e01d0>
# <generator object <genexpr> at 0x7f7bff5e01d0>

# %% [markdown]
# Q. Write a Program to take a Tuple of Numbers from the Keyboard and Print its Sum and Average?

# %%
t=eval(input("Enter Tuple of Numbers:"))
l=len(t)
sum=0
for x in t:
  sum=sum+x
print("The Sum=",sum)
print("The Average=",sum/l)
# Out:
# Enter Tuple of Numbers:2,3,4,5
# The Sum= 14
# The Average= 3.5

# %% [markdown]
# ![image.png](data:image/png;base64,...)
